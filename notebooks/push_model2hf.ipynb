# %%
from huggingface_hub import HfApi
from dotenv import load_dotenv
import os

load_dotenv()

api = HfApi(token=os.getenv("HF_TOKEN"))
api.upload_folder(
    folder_path="../pneumonia_baseline_cnn_20251118_091549",
    repo_id="wuxdas/pneumonia_cnn",
    repo_type="model",
)
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/wuxdas/pneumonia_cnn/commit/31b4fb18a809fedc55b7d30cee3f1717b1d36006', commit_message='Upload folder using huggingface_hub', commit_description='', oid='31b4fb18a809fedc55b7d30cee3f1717b1d36006', pr_url=None, repo_url=RepoUrl('https://huggingface.co/wuxdas/pneumonia_cnn', endpoint='https://huggingface.co', repo_type='model', repo_id='wuxdas/pneumonia_cnn'), pr_revision=None, pr_num=None)
